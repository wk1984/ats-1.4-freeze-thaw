# %% [markdown]
# #### It doesn't matter which version of ATS used here.
#
# ##### We here use ATS 1.2, these functions are used to create a column mesh file.

# %%
import sys,os
import numpy as np
from matplotlib import pyplot as plt

# This is the standard path for SEACAS if Amanzi TPLS are built via
# bootstrap with --build-shared
try:
    import exodus
except ImportError:
    sys.path.append(os.path.join(os.environ['AMANZI_TPLS_DIR'],'SEACAS', 'lib'))
    import exodus

# This is the standard path for ATS's source directory    
try:
    import meshing_ats
except ImportError:
    sys.path.append(os.path.join(os.environ['ATS_SRC_DIR'],'tools','meshing','meshing_ats'))
    import meshing_ats

# set up the surface mesh
# -- generate some topography
x = np.linspace(-50.0, 50.0, 21)
z = 5. - 2*np.cos(np.pi/100. * x)**2

plt.plot(x,z)
plt.show()

# %%
# -- using from_Transect extrudes the x,z line in the y-direction to
#    create 1 cell in y.  This results in a transect across our
#    topography
m2 = meshing_ats.Mesh2D.from_Transect(x,z)

# %%
# layer extrusion
# -- data structures needed for extrusion
layer_types = []
layer_data = []
layer_ncells = []
layer_mat_ids = []
z = 0.0

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(10)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

layer_types.append("constant")
layer_data.append(0.10)
layer_ncells.append(2)
layer_mat_ids.append(1002)
z += 0.10

#----------------------------------
# ^^^ TOP 100 cm ^^^
#----------------------------------

layer_types.append("constant")
layer_data.append(1.00)
layer_ncells.append(10)
layer_mat_ids.append(1002)
z += 1.0

#----------------------------------
# ^^^ TOP 200 cm ^^^
#----------------------------------

layer_types.append("constant")
layer_data.append(2.0)
layer_ncells.append(20)
layer_mat_ids.append(1002)
z += 2.0

#----------------------------------
# ^^^ TOP 400 cm ^^^
#----------------------------------

layer_types.append("constant")
layer_data.append(6.0)
layer_ncells.append(12)
layer_mat_ids.append(1002)
z += 6.0

#----------------------------------
# ^^^ TOP 10 m ^^^
#----------------------------------

layer_types.append("constant")
layer_data.append(5.0)
layer_ncells.append(5)
layer_mat_ids.append(1002)
z += 5.0

#----------------------------------
# ^^^ TOP 15 m ^^^
#----------------------------------


layer_types.append("constant")
layer_data.append(5.0)
layer_ncells.append(5)
layer_mat_ids.append(1002)
z += 5.0

#----------------------------------
# ^^^ TOP 20 m ^^^
#----------------------------------


layer_types.append("constant")
layer_data.append(10.0)
layer_ncells.append(5)
layer_mat_ids.append(1002)
z += 10.0

print(z)

#----------------------------------
# ^^^ TOP 30 m ^^^
#----------------------------------


# layer_types.append("constant")
# layer_data.append(12.0)
# layer_ncells.append(4)
# layer_mat_ids.append(1002)
# z += 12.0

# print(z)

# -- mineral layer part 5 --
# keep going for 2m cells until we hit the bottom of
# the domain
layer_types.append("snapped")
layer_data.append(-36) # depth of bottom of domain is 40 m

print(int(round((-layer_data[-1]-z) / 2.0)))

layer_ncells.append(int(round((-layer_data[-1]-z) / 2.0)))
layer_mat_ids.append(1002)
# Out:
# 30.0
# 3

# %%
meshing_ats.summarize_extrusion(layer_types, layer_data, layer_ncells, layer_mat_ids)
# Out:
# Cell summary:
# ------------------------------------------------------------
# l_id	| c_id	|mat_id	| dz		| z_top
# ------------------------------------------------------------
#  00 	| 00 	| 1002 	|   0.010000 	|   0.000000
#  00 	| 01 	| 1002 	|   0.010000 	|   0.010000
#  00 	| 02 	| 1002 	|   0.010000 	|   0.020000
#  00 	| 03 	| 1002 	|   0.010000 	|   0.030000
#  00 	| 04 	| 1002 	|   0.010000 	|   0.040000
#  00 	| 05 	| 1002 	|   0.010000 	|   0.050000
#  00 	| 06 	| 1002 	|   0.010000 	|   0.060000
#  00 	| 07 	| 1002 	|   0.010000 	|   0.070000
#  00 	| 08 	| 1002 	|   0.010000 	|   0.080000
#  00 	| 09 	| 1002 	|   0.010000 	|   0.090000
#  01 	| 10 	| 1002 	|   0.050000 	|   0.100000
#  01 	| 11 	| 1002 	|   0.050000 	|   0.150000
#  02 	| 12 	| 1002 	|   0.050000 	|   0.200000
#  02 	| 13 	| 1002 	|   0.050000 	|   0.250000
#  03 	| 14 	| 1002 	|   0.050000 	|   0.300000
#  03 	| 15 	| 1002 	|   0.050000 	|   0.350000
#  04 	| 16 	| 1002 	|   0.050000 	|   0.400000
# ...

# %%
# Extrude the 3D model with this structure and write to file
m3 = meshing_ats.Mesh3D.extruded_Mesh2D(m2, layer_types, 
                                        layer_data, 
                                        layer_ncells, 
                                        layer_mat_ids)

# %%
# if os.path.exists('../data/column.exo'):
#     os.remove('../data/column.exo')
# m3.write_exodus("../data/column.exo")

if os.path.exists('mesh2D.exo'):
    os.remove('mesh2D.exo')
m3.write_exodus("mesh2D.exo")
# Out:
# You are using exodus.py v 1.20.10 (seacas-py3), a python wrapper of some of the exodus library.
#
# Copyright (c) 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021 National Technology &
# Engineering Solutions of Sandia, LLC (NTESS).  Under the terms of
# Contract DE-NA0003525 with NTESS, the U.S. Government retains certain
# rights in this software.
#
# Opening exodus file: mesh2D.exo
# Closing exodus file: mesh2D.exo
